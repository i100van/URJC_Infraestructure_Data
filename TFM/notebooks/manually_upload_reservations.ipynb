# %%
df
# Out:
#       CURSO_ACADEMICO  CODALF                                      PLAN  \
# 0             2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 1             2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 2             2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 3             2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 4             2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# ...               ...     ...                                       ...
# 58906         2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 58907         2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 58908         2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 58909         2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
# 58910         2018-19    2107  GRADO EN INGENIERIA AMBIENTAL (MOSTOLES)
#
#                                              ASIGNATURA  COD_ASIGNATURA  \
# ...

# %%
import pandas as pd
df = pd.read_csv('C:/Users/i100v/PycharmProjects/TFM/data/temporary/tfm_raw_myapps_classreservation.csv')
df.columns=['CURSO_ACADEMICO', 'CODALF', 'PLAN', 'ASIGNATURA', 'COD_ASIGNATURA',
            'GRUPO', 'MATRICULADOS', 'SOFTWARE', 'OBSERVACIONES', 'CARACTER',
            'TIPO_AULA', 'CODSOL', 'FECHA_PUNTUAL', 'HORA_INICIO_PUNTUAL',
            'HORA_FIN_PUNTUAL', 'FECHA_EXAMEN', 'HORA_INICIO_EXAMEN', 'HORA_FIN_EXAMEN',
            'FECHA_INICIO_PERIODICA', 'FECHA_FIN_PERIODICA', 'DIA_SEMANA_PERIODICA',
            'HORA_INICIO_PERIODICA', 'HORA_FIN_PERIODICA', 'CAMPUS', 'EDIFICIO', 'AULA',
            'CAPACIDAD_DISPONIBLE']
from data_processers.tables_processers import Data_Processer
p = Data_Processer()
df2 = p.reservations(df)
df2.to_csv('C:/Users/i100v/PycharmProjects/TFM/data/temporary/tfm_raw_myapps_classreservation_p.csv',index=False,header=True)

# %%
df2
# Out:
#       CURSO_ACADEMICO CODALF                          PLAN    ASIGNATURA  \
# 1             2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 2             2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 4             2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 7             2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 9             2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# ...               ...    ...                           ...           ...
# 58904         2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 58904         2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 58904         2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 58904         2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
# 58904         2021-22   2000  GRADO EN MEDICINA (ALCORCON)  FARMACOLOGIA
#
#        COD_ASIGNATURA   GRUPO  MATRICULADOS SOFTWARE  \
# ...
